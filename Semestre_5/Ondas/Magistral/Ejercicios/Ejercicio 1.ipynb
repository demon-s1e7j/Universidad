# %% [markdown]
# # Librerias y Variables

# %%
import numpy as np
import matplotlib.pyplot as plt

Eje_independiente = np.linspace(0,10,100)

# %%
plt.plot(Eje_independiente, (0.1)*np.cos(Eje_independiente))
