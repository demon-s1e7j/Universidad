# %%
#%matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import matplotlib as mpl
import matplotlib.animation as animation
from tqdm import tqdm

# %%
Nt = 1000
Nx = 20
Ny = 20

x = np.linspace(0,2,Nx)
y = np.linspace(0,2,Nx)
t = np.linspace(0,100,Nt)

deltax = x[1] - x[0]
deltay = y[1] - y[0]
deltat = t[1] - t[0]

k = 0.0075

alpha = 1.
beta = 1.
omega = 0.1/4

v = 3.

lambda_ = (k*deltat)/deltax**2
mu_ = (k*deltat)/deltay**2

print(lambda_,mu_)
# Out:
# 0.06775525525525526 0.06775525525525526

# %%
def ui(x,y):
    return np.sin(np.pi*x)*np.sin(np.pi*y)

# %%
def initT():
    u = np.zeros((Nt,Nx,Ny))
    for i in range(len(x)):
        for j in range(len(y)):
            u[0,i,j] = ui(x[i],y[j])
    return u

# %%
T = initT()
#print(T[0,:,:])

# %%
def GetSolution():
    
    for l in tqdm(range(1,len(t))):
        
        #T[l,0,:] = np.sin(20*t[l])
        
        for i in range(1,len(x)-1):
            for j in range(1,len(y)-1):
                T[l,i,j] = (1-2*lambda_-2*mu_)*T[l-1,i,j] + \
                lambda_*(T[l-1,i+1,j] + T[l-1,i-1,j]) + \
                mu_*(T[l-1,i,j+1] + T[l-1,i,j-1])

# %%
GetSolution()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 999/999 [00:00<00:00, 1561.14it/s]

# %%
# Este codigo sale del repositorio del curso. Sin emabargo, no funciona
# Bien en mi entorno.
# Estoy teniendo problemas en mi entorno al configurar ipympl dado
# que cambie de sistema operativo hace poco. Por lo tanto adicionare
# Otro codigo para mostrar que el resultado es correcto pero deberia 
# funcionar en un entorno bien configurado. en donde solo deberia quitar
# el comentario que se puso en el inicio
fig = plt.figure(figsize=(5,6))
ax = fig.add_subplot(111, projection='3d')

X,Y = np.meshgrid(x,y)

def init():
    
    
    ax.set_xlim3d(0,2)
    ax.set_ylim3d(0,2)
    ax.set_zlim3d(0,10)

def Update(i):

    ax.clear()
    init()
    
    ax.plot_surface(X,Y,T[i,:,:],cmap='viridis')
    
Animation = animation.FuncAnimation(fig,Update,frames=len(t),init_func=init)

# %%
fig = plt.figure(figsize=(5,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X,Y,T[-1,:,:],cmap='viridis')
