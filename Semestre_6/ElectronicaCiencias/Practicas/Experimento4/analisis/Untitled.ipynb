# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("../data/1000hz-4.2-circuito4.3.csv")
fig, ax = plt.subplots()
ax.plot(data["x2"],data["y2"])
plt.show()

# %%
data = pd.read_csv("../data/400hz-4.2-circuito4.3.csv")
fig, ax = plt.subplots()
ax.plot(data["x"],data["y"])
ax.plot(data["x2"],data["y2"])
plt.show()

# %%
data = pd.read_csv("../data/600hz-4.2-circuito4.3.csv")
fig, ax = plt.subplots()
ax.plot(data["x2"],data["y2"])
plt.show()

# %%
data = pd.read_csv("../data/800hz-4.2-circuito4.3.csv")
fig, ax = plt.subplots()
ax.plot(data["x2"],data["y2"])
plt.show()

# %%
data = pd.read_csv("../data/electro.4.2-circuito4.3.csv")
fig, ax = plt.subplots()
ax.plot(data["x2"],data["y2"])
plt.show()

# %%
data = pd.read_csv("../data/Expi4-1_datosz-electro.csv")
fig, ax = plt.subplots()
ax.plot(data["x"],data["y"]/10 + 2.1)
ax.plot(data["x2"],data["y2"] + 1.8)
plt.show()

# %%
data = pd.read_csv("../data/hola1000hz-4.2-circuito4.5.csv")
fig, ax = plt.subplots()
ax.plot(data["x2"],data["y2"])
plt.show()

# %%
data = pd.read_csv("../data/hola100hz-4.2-circuito4.5.csv")
fig, ax = plt.subplots()
ax.plot(data["x2"],data["y2"])
plt.show()

# %%
data = pd.read_csv("../data/hola2000hz-4.2-circuito4.5.csv")
fig, ax = plt.subplots()
ax.plot(data["x2"],data["y2"])
plt.show()

# %%
data = pd.read_csv("../data/hola200hz-4.2-circuito4.5.csv")
fig, ax = plt.subplots()
ax.plot(data["x2"],data["y2"])
plt.show()

# %%
data = pd.read_csv("../data/hola20hz-4.2-circuito4.5.csv")
fig, ax = plt.subplots()
ax.plot(data["x2"],data["y2"])
plt.show()

# %%
data = pd.read_csv("../data/hola500hz-4.2-circuito4.5.csv")
fig, ax = plt.subplots()
ax.plot(data["x2"],data["y2"])
plt.show()

# %%
data = pd.read_csv("../data/hola50hz-4.2-circuito4.5.csv")
fig, ax = plt.subplots()
ax.plot(data["x2"],data["y2"])
plt.show()
